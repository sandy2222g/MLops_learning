# %%
import pickle
import pandas as pd
import numpy as np
from sklearn import linear_model

# %%
with open('linear_model_pickle','rb') as file:
    m = pickle.load(file)

# %%
m.coef_
# Out:
# array([135.78767123])

# %%
m.intercept_
# Out:
# 180616.43835616432

# %%
m.predict([[5000]])
# Out:
# c:\Users\sanjay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([859554.79452055])
