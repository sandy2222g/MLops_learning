# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv("machine_failure_dataset.csv")

# %%
x=df[['Power_Usage', 'Vibration', 'Humidity']]

# %%
y = df['Temperature']

# %%
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression()

# %%
p=model.predict(x)

# %%
mean_squared_error(y,p)
# Out:
# 95.56457765346364

# %%
model.predict([[8.4617153,60.37630436,23.56418216]])
# Out:
# c:\Users\sanjay\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([69.41002337])

# %%
df.corr(numeric_only=True)
# Out:
#               Temperature  Vibration  Power_Usage  Humidity  Failure_Risk
# Temperature      1.000000  -0.040400     0.022129 -0.013321      0.029938
# Vibration       -0.040400   1.000000    -0.011199 -0.054698     -0.001727
# Power_Usage      0.022129  -0.011199     1.000000  0.021586      0.020971
# Humidity        -0.013321  -0.054698     0.021586  1.000000     -0.018007
# Failure_Risk     0.029938  -0.001727     0.020971 -0.018007      1.000000

# %%
df2=pd.read_csv("factory_sensor_simulator_2040.csv")

# %%
df2.corr(numeric_only=True)
# Out:
#                             Installation_Year  Operational_Hours  \
# Installation_Year                    1.000000           0.000625
# Operational_Hours                    0.000625           1.000000
# Temperature_C                        0.000934          -0.000758
# Vibration_mms                       -0.000878          -0.001896
# Sound_dB                             0.000196           0.000883
# Oil_Level_pct                       -0.000762           0.002059
# Coolant_Level_pct                   -0.002217          -0.001338
# Power_Consumption_kW                 0.000576          -0.000113
# Last_Maintenance_Days_Ago           -0.000942          -0.002554
# Maintenance_History_Count           -0.000827          -0.000092
# Failure_History_Count               -0.000897           0.000598
# AI_Supervision                      -0.000165          -0.001895
# Error_Codes_Last_30_Days            -0.000371          -0.003748
# ...

# %%
df2=pd.read_csv("industrial_fault_detection_data_1000.csv")

# %%
df2.corr(numeric_only=True)
# Out:
#                   Vibration (mm/s)  Temperature (°C)  Pressure (bar)  \
# Vibration (mm/s)          1.000000          0.029310        0.014518
# Temperature (°C)          0.029310          1.000000        0.027262
# Pressure (bar)            0.014518          0.027262        1.000000
# RMS Vibration                  NaN               NaN             NaN
# Mean Temp                      NaN               NaN             NaN
# Fault Label              -0.031799         -0.007783        0.008727
#
#                   RMS Vibration  Mean Temp  Fault Label
# Vibration (mm/s)            NaN        NaN    -0.031799
# Temperature (°C)            NaN        NaN    -0.007783
# Pressure (bar)              NaN        NaN     0.008727
# RMS Vibration               NaN        NaN          NaN
# Mean Temp                   NaN        NaN          NaN
# Fault Label                 NaN        NaN     1.000000

# %%
import pickle
with open("temperature_model.pkl", "wb") as f:
    pickle.dump(model, f)
